# %%
pip install pandas==2.0.3 numpy matplotlib yfinance==0.2.65 scikit-learn tensorflow vaderSentiment newsapi-python
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\marlo\anaconda3\Lib\site-packages\~umpy.libs'.
#   You can safely remove it manually.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\marlo\anaconda3\Lib\site-packages\~-mpy'.
#   You can safely remove it manually.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\marlo\anaconda3\Lib\site-packages\~andas.libs'.
#   You can safely remove it manually.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\marlo\anaconda3\Lib\site-packages\~~ndas'.
#   You can safely remove it manually.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# daal4py 2021.5.0 requires daal==2021.4.0, which is not installed.
# ...

# %%
# Out:
# ...
#   Using cached yfinance-0.2.65-py2.py3-none-any.whl.metadata (5.8 kB)
# ...
#      -------------------------------------- 59.7/59.7 kB 526.6 kB/s eta 0:00:00
# ...
#   Using cached requests-2.32.4-py3-none-any.whl.metadata (4.9 kB)
# ...
#   Using cached platformdirs-4.3.8-py3-none-any.whl.metadata (12 kB)
# ...
#   Using cached pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# ...
#   Using cached frozendict-2.4.6-cp39-cp39-win_amd64.whl.metadata (23 kB)
# ...
#   Using cached peewee-3.18.2-py3-none-any.whl
# ...
#   Using cached curl_cffi-0.12.0-cp39-abi3-win_amd64.whl.metadata (15 kB)
# ...
#   Using cached websockets-15.0.1-cp39-cp39-win_amd64.whl.metadata (7.0 kB)
# ...
#   Using cached certifi-2025.7.9-py3-none-any.whl.metadata (2.4 kB)
# ...
#   Using cached python_dateutil-2.9.0.post0-py2.py3-none-any.whl.metadata (8.4 kB)
# ...
#   Using cached tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# ...
#   Using cached six-1.17.0-py2.py3-none-any.whl.metadata (1.7 kB)
# Using cached yfinance-0.2.65-py2.py3-none-any.whl (119 kB)
# ...
